# %%
import os
import pandas as pd
import numpy as np
import pickle
import time

import matplotlib.pyplot as plt
import seaborn as sns
import module1_Preprocessing as module1
import module2_FeatureExtraction as module2
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score, accuracy_score , roc_auc_score, confusion_matrix

os.chdir('../')
LIWCPath=os.path.join('Source Code','LIWC')
seed=123

# %%
file_list=[]
for root,subdir,files in os.walk(os.path.join('Source Code','Processed','Kaggle50')):
    file_list.extend([os.path.join(root,file) for file in files if file.endswith('.pickle')])
file_list=file_list[7:]
file_list
# Out:
# ['Source Code\\Processed\\Kaggle50\\kaggle_noNN.pickle',
#  'Source Code\\Processed\\Kaggle50\\kaggle_noNNnoSW.pickle',
#  'Source Code\\Processed\\Kaggle50\\kaggle_noNNnoSW_lgbfeatures.pickle',
#  'Source Code\\Processed\\Kaggle50\\kaggle_noSW.pickle',
#  'Source Code\\Processed\\Kaggle50\\kaggle_noSW_lgbfeatures.pickle']

# %% [markdown]
# ### Define Models

# %%
from sklearn.naive_bayes import ComplementNB
cnb = ComplementNB()
cnb
# Out:
# ComplementNB(alpha=1.0, class_prior=None, fit_prior=True, norm=False)

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(n_estimators=100,random_state=123, class_weight='balanced', n_jobs=10 )
rf
# Out:
# RandomForestClassifier(bootstrap=True, class_weight='balanced',
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        n_estimators=100, n_jobs=10, oob_score=False,
#                        random_state=123, verbose=0, warm_start=False)

# %%
from sklearn.linear_model import LogisticRegression
lgr=LogisticRegression(random_state=123, solver= 'liblinear',class_weight='balanced')
lgr
# Out:
# LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#                    fit_intercept=True, intercept_scaling=1, l1_ratio=None,
#                    max_iter=100, multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=123, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
from sklearn import svm
svc = svm.SVC(random_state=seed, verbose=True, C = 1.0, class_weight='balanced', probability=True, gamma='auto')
svc
# Out:
# SVC(C=1.0, cache_size=200, class_weight='balanced', coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#     max_iter=-1, probability=True, random_state=123, shrinking=True, tol=0.001,
#     verbose=True)

# %%
import lightgbm as lgb
lgb = lgb.LGBMClassifier(objective='binary',metric='auc,binary_logloss',boosting_type='gbdt', class_weight='balanced',
                               learning_rate=0.01,n_estimators=10000,
                              random_state=seed,n_jobs=10)
lgb
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight='balanced',
#                colsample_bytree=1.0, importance_type='split',
#                learning_rate=0.01, max_depth=-1, metric='auc,binary_logloss',
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=10000, n_jobs=10, num_leaves=31, objective='binary',
#                random_state=123, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
from sklearn.ensemble import VotingClassifier
ensemble_list=[('svc',svc),('lgb',lgr)]
vote= VotingClassifier(estimators=ensemble_list,voting='soft')

# %% [markdown]
# ### Training with 5-folds Cross Validation. Loop for 4 different models and different files

# %%
# %%time

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer,TfidfTransformer
from sklearn.preprocessing import QuantileTransformer, quantile_transform

scaler=QuantileTransformer(random_state=seed) 
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state = seed)
result_list=[]
all_result_list=[]
result_fileDF=pd.DataFrame()
models=[('lgb',lgb),('cnb',cnb),('rf',rf),('lgr',lgr),('svc',svc)]

for filepath in file_list[:]:
    result_list=[]
    dir = os.path.split(filepath)[0]
    file = os.path.split(filepath)[1].replace('.pickle','')
    print('processing file:',file)
    
    with open(filepath, 'rb') as handle:
        data = pickle.load(handle)
    
        label=data[['MBTI','EI','SN','TF','JP']]
    
    data['tokens']=data['tokens'].apply(lambda x: ' '.join(x))
    
    start_time = time.time()
    print('converting to tfidf')
    cCount_Vect=CountVectorizer(analyzer='char_wb', ngram_range=(2,3),min_df=50, max_df=0.95, max_features=1500)
    wCount_Vect=CountVectorizer(tokenizer = module2.dummy, preprocessor=module2.dummy, token_pattern=module2.dummy,
                           analyzer='char_wb', ngram_range=(2,3),min_df=50, max_df=0.95, max_features=1500)
    TFIDF_Trans=TfidfTransformer(use_idf=True, sublinear_tf=False)
    cTfidf_Vect=TfidfVectorizer(analyzer='char_wb', ngram_range=(2,3),min_df=50, max_df=0.95, max_features=1500)
    wTfidf_Vect=TfidfVectorizer(tokenizer = module2.dummy, preprocessor=module2.dummy, token_pattern=module2.dummy, 
                                ngram_range=(1,3),min_df=50, max_df=0.95, max_features=1500)
    
    char_tf, char_tf_top=module2.df2vector(data['tokens'], cCount_Vect, 1500)
    word_tf, word_tf_top=module2.df2vector(data['tokens'], wCount_Vect, 1500)
    
    char_tfidf, char_tfidf_top=module2.df2vector(data['tokens'], cTfidf_Vect, 1500)
    word_tfidf, word_tfidf_top=module2.df2vector(data['tokens'], wTfidf_Vect, 1500)
    print("--- %s seconds ---" % (time.time() - start_time))
    del data
    
    LIWC=module2.LIWC(LIWCPath,filepath)

    combo = np.hstack([LIWC,word_tfidf, char_tfidf, word_tf, char_tf])    
    char_tf_col=char_tf_top[0].tolist()
    word_tf_col=word_tf_top[0].tolist()
    char_tfidf_col=char_tfidf_top[0].tolist()
    word_tfidf_col=word_tfidf_top[0].tolist()
    LIWC_col=LIWC.columns.tolist()
    
    char_tf=scaler.fit_transform(char_tf)
    word_tf=scaler.fit_transform(word_tf)
    char_tfidf=scaler.fit_transform(char_tfidf)
    word_tfidf=scaler.fit_transform(word_tfidf)
    LIWC=scaler.fit_transform(LIWC)
    

    
    features = [('combo',combo),('char_tf',char_tf), ('word_tf',word_tf), ('char_tfidf',char_tfidf), ('word_tfidf',word_tfidf),('LIWC',LIWC)]
    for feature_name,feature in features:    
        X=feature
        feature_col=[]
        if feature_name =='combo':
            feature_col=LIWC_col
            feature_col.extend(word_tfidf_col)
            feature_col.extend(char_tfidf_col)
            feature_col.extend(word_tf_col)
            feature_col.extend(char_tf_col)
        elif feature_name =='char_tfidf':
            feature_col =char_tfidf_col
        elif feature_name =='word_tfidf':
            feature_col =word_tfidf_col      
        elif feature_name =='LIWC':
            feature_col = LIWC_col
        
        
        for y_class in ['JP']:
            y=label[y_class]
            split = 0
            print('\n\n\nPerforming training and classification on:',file, feature_name, y_class)

            for train_index, test_index in skf.split(X, y):
                
                split += 1
                X_train, X_test = X[train_index,:],X[test_index,:]
                y_train, y_test = y[train_index],y[test_index]

                print('\nNow on split#',split, feature_name, y_class )
                for model_name, model in models:
                    result = {}
                    start_time = time.time()
                    if model_name == 'lgb':
                        lgb.fit(X_train,y_train,eval_set=[(X_test,y_test)],eval_metric='f1_score',
                                verbose=100,early_stopping_rounds=300)
                        y_pred =lgb.predict(X_test)
                        y_pred_proba = lgb.predict_proba(X_test)[:,1]
                        
                        # sorted(zip(clf.feature_importances_, X.columns), reverse=True)
                        feature_imp = pd.DataFrame(sorted(zip(lgb.feature_importances_,feature_col)), columns=['Value','Feature'])

                        plt.figure(figsize=(20, 10))
                        sns.barplot(x="Value", y="Feature", data=feature_imp.sort_values(by="Value", ascending=False)[:20])
                        plt.title('LightGBM Features (avg over folds)')
                        plt.tight_layout()
                        plt.show()
                        plt.savefig(filepath.replace('.pickle',f'_{feature_name}_lgb_importances.png'), format='png')
                        with open(filepath.replace('.pickle','_lgbfeatures.pickle'), 'wb') as handle:
                            pickle.dump(feature_imp, handle, protocol=pickle.HIGHEST_PROTOCOL)
                    else:
                        model.fit(X_train,y_train)
                        y_pred =model.predict(X_test)
                        y_pred_proba = model.predict_proba(X_test)[:,1]
                    f1=f1_score(y_test, y_pred, average='macro') 
                    accuracy=accuracy_score(y_test, y_pred)
                    cm=confusion_matrix(y_test, y_pred)
                    auc=roc_auc_score(y_test, y_pred_proba)
                    seconds=time.time() - start_time
                    print(model_name, accuracy, f1,auc)
                    result['file'] = file
                    result['cv_split#'] = split
                    result['class'] = y_class
                    result['Feature'] = feature_name
                    result['model'] = model_name
                    result['CM'] = cm
                    result['Acc'] = accuracy
                    result['f1-macro'] = f1
                    result['auc'] = auc
                    result['time-s'] = seconds
                    result_list.append(result)
                    print("--- %s seconds ---" %seconds)
    all_result_list.extend(result_list)
    result_fileDF = pd.DataFrame(result_list)
    result_fileDF.to_csv(filepath.replace('.pickle','_result.csv'))
# Out:
# processing file: kaggle_noNN
# converting to tfidf
# --- 72.48924899101257 seconds ---
#
#
#
# Performing training and classification on: kaggle_noNN char_tfidf JP
#
# Now on split# 1 char_tfidf JP
# Training until validation scores don't improve for 300 rounds
# [100]	valid_0's auc: 0.617823	valid_0's binary_logloss: 0.675342
# [200]	valid_0's auc: 0.62694	valid_0's binary_logloss: 0.666319
# [300]	valid_0's auc: 0.622786	valid_0's binary_logloss: 0.662848
# [400]	valid_0's auc: 0.625161	valid_0's binary_logloss: 0.659476
# [500]	valid_0's auc: 0.622811	valid_0's binary_logloss: 0.658275
# Early stopping, best iteration is:
# [213]	valid_0's auc: 0.628392	valid_0's binary_logloss: 0.665197
# lgb 0.6035879629629629 0.5896017748974334 0.6283917008357419
# --- 50.89394211769104 seconds ---
# cnb 0.5833333333333334 0.5751376868607396 0.6172069301606506
# --- 0.04188728332519531 seconds ---
#
# Now on split# 2 char_tfidf JP
# Training until validation scores don't improve for 300 rounds
# [100]	valid_0's auc: 0.60373	valid_0's binary_logloss: 0.676655
# [200]	valid_0's auc: 0.621768	valid_0's binary_logloss: 0.66692
# [300]	valid_0's auc: 0.624864	valid_0's binary_logloss: 0.662379
# [400]	valid_0's auc: 0.625815	valid_0's binary_logloss: 0.659273
# [500]	valid_0's auc: 0.628187	valid_0's binary_logloss: 0.655995
# [600]	valid_0's auc: 0.629795	valid_0's binary_logloss: 0.653701
# [700]	valid_0's auc: 0.630781	valid_0's binary_logloss: 0.65201
# [800]	valid_0's auc: 0.63005	valid_0's binary_logloss: 0.651549
# [900]	valid_0's auc: 0.629805	valid_0's binary_logloss: 0.651111
# Early stopping, best iteration is:
# [669]	valid_0's auc: 0.631106	valid_0's binary_logloss: 0.652355
# lgb 0.6064814814814815 0.5802469135802469 0.631105621653111
# --- 91.54123497009277 seconds ---
# cnb 0.5763888888888888 0.5673326756705356 0.6040728417467679
# --- 0.04388022422790527 seconds ---
#
# Now on split# 3 char_tfidf JP
# Training until validation scores don't improve for 300 rounds
# [100]	valid_0's auc: 0.591152	valid_0's binary_logloss: 0.679437
# [200]	valid_0's auc: 0.598234	valid_0's binary_logloss: 0.672963
# [300]	valid_0's auc: 0.598287	valid_0's binary_logloss: 0.670295
# [400]	valid_0's auc: 0.59867	valid_0's binary_logloss: 0.668576
# [500]	valid_0's auc: 0.600704	valid_0's binary_logloss: 0.66731
# [600]	valid_0's auc: 0.600925	valid_0's binary_logloss: 0.666573
# [700]	valid_0's auc: 0.600472	valid_0's binary_logloss: 0.666506
# [800]	valid_0's auc: 0.599937	valid_0's binary_logloss: 0.666666
# [900]	valid_0's auc: 0.599672	valid_0's binary_logloss: 0.66692
# Early stopping, best iteration is:
# [622]	valid_0's auc: 0.601922	valid_0's binary_logloss: 0.666199
# lgb 0.6108859293572669 0.5863012995457151 0.6019224404391265
# --- 87.12185978889465 seconds ---
# cnb 0.5911986103068906 0.5817925752748805 0.6192409529739766
# --- 0.041887521743774414 seconds ---
#
# Now on split# 4 char_tfidf JP
# Training until validation scores don't improve for 300 rounds
# [100]	valid_0's auc: 0.598632	valid_0's binary_logloss: 0.679312
# [200]	valid_0's auc: 0.608827	valid_0's binary_logloss: 0.671899
# [300]	valid_0's auc: 0.611609	valid_0's binary_logloss: 0.66743
# [400]	valid_0's auc: 0.613434	valid_0's binary_logloss: 0.664732
# [500]	valid_0's auc: 0.614784	valid_0's binary_logloss: 0.662445
# [600]	valid_0's auc: 0.616516	valid_0's binary_logloss: 0.660495
# [700]	valid_0's auc: 0.617489	valid_0's binary_logloss: 0.659375
# [800]	valid_0's auc: 0.617904	valid_0's binary_logloss: 0.658477
# [900]	valid_0's auc: 0.617338	valid_0's binary_logloss: 0.658252
# [1000]	valid_0's auc: 0.618015	valid_0's binary_logloss: 0.657794
# [1100]	valid_0's auc: 0.618885	valid_0's binary_logloss: 0.657205
# [1200]	valid_0's auc: 0.618423	valid_0's binary_logloss: 0.657473
# [1300]	valid_0's auc: 0.619568	valid_0's binary_logloss: 0.657079
# [1400]	valid_0's auc: 0.619843	valid_0's binary_logloss: 0.657325
# [1500]	valid_0's auc: 0.619427	valid_0's binary_logloss: 0.657729
# [1600]	valid_0's auc: 0.619153	valid_0's binary_logloss: 0.658458
# Early stopping, best iteration is:
# [1336]	valid_0's auc: 0.620502	valid_0's binary_logloss: 0.656651
# lgb 0.6039374638100753 0.578148703664024 0.6205017305890734
# --- 145.4722204208374 seconds ---
# cnb 0.5778807180081066 0.5738479947060307 0.6232182225139261
# --- 0.055848121643066406 seconds ---
#
# Now on split# 5 char_tfidf JP
# Training until validation scores don't improve for 300 rounds
# [100]	valid_0's auc: 0.606681	valid_0's binary_logloss: 0.676269
# [200]	valid_0's auc: 0.61502	valid_0's binary_logloss: 0.668234
# [300]	valid_0's auc: 0.616785	valid_0's binary_logloss: 0.664065
# [400]	valid_0's auc: 0.618385	valid_0's binary_logloss: 0.661009
# [500]	valid_0's auc: 0.618292	valid_0's binary_logloss: 0.659081
# [600]	valid_0's auc: 0.620039	valid_0's binary_logloss: 0.657133
# [700]	valid_0's auc: 0.618778	valid_0's binary_logloss: 0.656465
# [800]	valid_0's auc: 0.620506	valid_0's binary_logloss: 0.655129
# [900]	valid_0's auc: 0.622319	valid_0's binary_logloss: 0.653995
# [1000]	valid_0's auc: 0.62282	valid_0's binary_logloss: 0.653251
# [1100]	valid_0's auc: 0.623145	valid_0's binary_logloss: 0.653125
# [1200]	valid_0's auc: 0.624741	valid_0's binary_logloss: 0.652396
# [1300]	valid_0's auc: 0.625764	valid_0's binary_logloss: 0.651914
# [1400]	valid_0's auc: 0.625928	valid_0's binary_logloss: 0.652104
# [1500]	valid_0's auc: 0.628106	valid_0's binary_logloss: 0.651683
# [1600]	valid_0's auc: 0.629017	valid_0's binary_logloss: 0.651856
# [1700]	valid_0's auc: 0.631164	valid_0's binary_logloss: 0.651414
# [1800]	valid_0's auc: 0.631871	valid_0's binary_logloss: 0.651828
# [1900]	valid_0's auc: 0.632784	valid_0's binary_logloss: 0.651984
# [2000]	valid_0's auc: 0.632218	valid_0's binary_logloss: 0.653307
# Early stopping, best iteration is:
# [1719]	valid_0's auc: 0.631828	valid_0's binary_logloss: 0.651194
# lgb 0.6276780544296467 0.5842783953817904 0.6318276927909886
# --- 179.51943707466125 seconds ---
# cnb 0.6010422698320788 0.5931856807464386 0.6300816770726398
# --- 0.045877933502197266 seconds ---
#
#
#
# Performing training and classification on: kaggle_noNN word_tfidf JP
#
# Now on split# 1 word_tfidf JP
# Training until validation scores don't improve for 300 rounds
# [100]	valid_0's auc: 0.60282	valid_0's binary_logloss: 0.678541
# [200]	valid_0's auc: 0.61452	valid_0's binary_logloss: 0.669773
# [300]	valid_0's auc: 0.614557	valid_0's binary_logloss: 0.665373
# [400]	valid_0's auc: 0.608481	valid_0's binary_logloss: 0.664292
# [500]	valid_0's auc: 0.607591	valid_0's binary_logloss: 0.662915
# Early stopping, best iteration is:
# [265]	valid_0's auc: 0.616704	valid_0's binary_logloss: 0.666087
# lgb 0.5949074074074074 0.5785929687456451 0.6167041966346262
# --- 61.005523920059204 seconds ---
# cnb 0.5740740740740741 0.5665276073619632 0.6064184647442361
# --- 0.049868106842041016 seconds ---
#
# Now on split# 2 word_tfidf JP
# Training until validation scores don't improve for 300 rounds
# [100]	valid_0's auc: 0.596451	valid_0's binary_logloss: 0.677452
# [200]	valid_0's auc: 0.609246	valid_0's binary_logloss: 0.669522
# [300]	valid_0's auc: 0.615718	valid_0's binary_logloss: 0.664414
# [400]	valid_0's auc: 0.620925	valid_0's binary_logloss: 0.660348
# [500]	valid_0's auc: 0.626365	valid_0's binary_logloss: 0.65695
# [600]	valid_0's auc: 0.625885	valid_0's binary_logloss: 0.655745
# [700]	valid_0's auc: 0.625914	valid_0's binary_logloss: 0.655142
# [800]	valid_0's auc: 0.625872	valid_0's binary_logloss: 0.654658
# Early stopping, best iteration is:
# [501]	valid_0's auc: 0.626434	valid_0's binary_logloss: 0.656915
# lgb 0.6024305555555556 0.5752666801430404 0.626433980865318
# --- 82.3247721195221 seconds ---
# cnb 0.5746527777777778 0.567183684875045 0.6026738701799198
# --- 0.04391622543334961 seconds ---
#
# Now on split# 3 word_tfidf JP
# Training until validation scores don't improve for 300 rounds
# [100]	valid_0's auc: 0.584353	valid_0's binary_logloss: 0.680184
# [200]	valid_0's auc: 0.592622	valid_0's binary_logloss: 0.674152
# [300]	valid_0's auc: 0.598679	valid_0's binary_logloss: 0.670312
# [400]	valid_0's auc: 0.597763	valid_0's binary_logloss: 0.668863
# [500]	valid_0's auc: 0.598019	valid_0's binary_logloss: 0.667539
# [600]	valid_0's auc: 0.596898	valid_0's binary_logloss: 0.667042
# Early stopping, best iteration is:
# [321]	valid_0's auc: 0.59992	valid_0's binary_logloss: 0.669652
# lgb 0.5929357266936884 0.5693699138761819 0.5999197814465144
# --- 61.66579842567444 seconds ---
# cnb 0.5894614939200926 0.5817834920945032 0.6154726443513235
# --- 0.05040478706359863 seconds ---
#
# Now on split# 4 word_tfidf JP
# Training until validation scores don't improve for 300 rounds
# [100]	valid_0's auc: 0.590752	valid_0's binary_logloss: 0.679973
# [200]	valid_0's auc: 0.601385	valid_0's binary_logloss: 0.673054
# [300]	valid_0's auc: 0.601715	valid_0's binary_logloss: 0.669349
# [400]	valid_0's auc: 0.60568	valid_0's binary_logloss: 0.665946
# [500]	valid_0's auc: 0.604323	valid_0's binary_logloss: 0.664754
# [600]	valid_0's auc: 0.603095	valid_0's binary_logloss: 0.663997
# [700]	valid_0's auc: 0.601782	valid_0's binary_logloss: 0.663918
# Early stopping, best iteration is:
# [409]	valid_0's auc: 0.606597	valid_0's binary_logloss: 0.665573
# lgb 0.5969889982628837 0.5752150090753337 0.6065967138441516
# --- 68.92747521400452 seconds ---
# cnb 0.5975680370584829 0.5928452240943061 0.6337798645821062
# --- 0.041846513748168945 seconds ---
#
# Now on split# 5 word_tfidf JP
# Training until validation scores don't improve for 300 rounds
# [100]	valid_0's auc: 0.604378	valid_0's binary_logloss: 0.676939
# [200]	valid_0's auc: 0.61755	valid_0's binary_logloss: 0.667331
# [300]	valid_0's auc: 0.621771	valid_0's binary_logloss: 0.661726
# [400]	valid_0's auc: 0.624569	valid_0's binary_logloss: 0.658112
# [500]	valid_0's auc: 0.628726	valid_0's binary_logloss: 0.654758
# [600]	valid_0's auc: 0.628856	valid_0's binary_logloss: 0.652943
# [700]	valid_0's auc: 0.629878	valid_0's binary_logloss: 0.651592
# [800]	valid_0's auc: 0.631369	valid_0's binary_logloss: 0.650255
# [900]	valid_0's auc: 0.631086	valid_0's binary_logloss: 0.649562
# [1000]	valid_0's auc: 0.631464	valid_0's binary_logloss: 0.64901
# [1100]	valid_0's auc: 0.630417	valid_0's binary_logloss: 0.649206
# [1200]	valid_0's auc: 0.63041	valid_0's binary_logloss: 0.649187
# Early stopping, best iteration is:
# [995]	valid_0's auc: 0.631874	valid_0's binary_logloss: 0.648935
# lgb 0.6108859293572669 0.5738695947196348 0.6318739727256919
# --- 116.22254681587219 seconds ---
# cnb 0.5987261146496815 0.5894201882790284 0.6296735721938933
# --- 0.048905134201049805 seconds ---
# processing file: kaggle_noNNnoSW
# converting to tfidf
# --- 34.375460624694824 seconds ---
#
#
#
# Performing training and classification on: kaggle_noNNnoSW char_tfidf JP
#
# Now on split# 1 char_tfidf JP
# Training until validation scores don't improve for 300 rounds
# [100]	valid_0's auc: 0.60107	valid_0's binary_logloss: 0.677148
# [200]	valid_0's auc: 0.605895	valid_0's binary_logloss: 0.670925
# [300]	valid_0's auc: 0.605805	valid_0's binary_logloss: 0.667427
# [400]	valid_0's auc: 0.603574	valid_0's binary_logloss: 0.66569
# Early stopping, best iteration is:
# [137]	valid_0's auc: 0.61041	valid_0's binary_logloss: 0.67304
# lgb 0.5821759259259259 0.5684661999501923 0.6104095247697788
# --- 46.22196674346924 seconds ---
# cnb 0.5787037037037037 0.5699888017917134 0.612183796016222
# --- 0.045874834060668945 seconds ---
#
# Now on split# 2 char_tfidf JP
# Training until validation scores don't improve for 300 rounds
# [100]	valid_0's auc: 0.593172	valid_0's binary_logloss: 0.678501
# [200]	valid_0's auc: 0.611832	valid_0's binary_logloss: 0.669539
# [300]	valid_0's auc: 0.61529	valid_0's binary_logloss: 0.665439
# [400]	valid_0's auc: 0.619494	valid_0's binary_logloss: 0.662268
# [500]	valid_0's auc: 0.620873	valid_0's binary_logloss: 0.660771
# [600]	valid_0's auc: 0.620632	valid_0's binary_logloss: 0.659957
# [700]	valid_0's auc: 0.619946	valid_0's binary_logloss: 0.6597
# Early stopping, best iteration is:
# [454]	valid_0's auc: 0.621961	valid_0's binary_logloss: 0.660834
# lgb 0.6116898148148148 0.5898206547867311 0.6219611928928324
# --- 77.10448360443115 seconds ---
# cnb 0.5775462962962963 0.5693774024182923 0.6024582129013467
# --- 0.04786968231201172 seconds ---
#
# Now on split# 3 char_tfidf JP
# Training until validation scores don't improve for 300 rounds
# [100]	valid_0's auc: 0.580101	valid_0's binary_logloss: 0.680623
# [200]	valid_0's auc: 0.586002	valid_0's binary_logloss: 0.674895
# [300]	valid_0's auc: 0.587032	valid_0's binary_logloss: 0.671893
# [400]	valid_0's auc: 0.587715	valid_0's binary_logloss: 0.670327
# [500]	valid_0's auc: 0.586935	valid_0's binary_logloss: 0.669853
# [600]	valid_0's auc: 0.587901	valid_0's binary_logloss: 0.66911
# [700]	valid_0's auc: 0.588755	valid_0's binary_logloss: 0.668303
# [800]	valid_0's auc: 0.589472	valid_0's binary_logloss: 0.668075
# [900]	valid_0's auc: 0.59043	valid_0's binary_logloss: 0.668104
# [1000]	valid_0's auc: 0.589557	valid_0's binary_logloss: 0.669089
# [1100]	valid_0's auc: 0.589902	valid_0's binary_logloss: 0.669377
# Early stopping, best iteration is:
# [876]	valid_0's auc: 0.591193	valid_0's binary_logloss: 0.667755
# lgb 0.5871453387376955 0.5559122392269089 0.5911925076992982
# --- 110.61855816841125 seconds ---
# cnb 0.5842501447596989 0.5751319161766923 0.6160336132568172
# --- 0.0418858528137207 seconds ---
#
# Now on split# 4 char_tfidf JP
# Training until validation scores don't improve for 300 rounds
# [100]	valid_0's auc: 0.590135	valid_0's binary_logloss: 0.680972
# [200]	valid_0's auc: 0.59959	valid_0's binary_logloss: 0.675295
# [300]	valid_0's auc: 0.604039	valid_0's binary_logloss: 0.671064
# [400]	valid_0's auc: 0.605191	valid_0's binary_logloss: 0.66871
# [500]	valid_0's auc: 0.605797	valid_0's binary_logloss: 0.667022
# [600]	valid_0's auc: 0.605799	valid_0's binary_logloss: 0.666155
# [700]	valid_0's auc: 0.607674	valid_0's binary_logloss: 0.664631
# [800]	valid_0's auc: 0.606886	valid_0's binary_logloss: 0.664475
# [900]	valid_0's auc: 0.605416	valid_0's binary_logloss: 0.664828
# [1000]	valid_0's auc: 0.60573	valid_0's binary_logloss: 0.664629
# Early stopping, best iteration is:
# [737]	valid_0's auc: 0.60787	valid_0's binary_logloss: 0.664502
# lgb 0.5946728430804864 0.5718173729726054 0.607870113259622
# --- 93.72486543655396 seconds ---
# cnb 0.57498552403011 0.5705761433976173 0.6181021860958248
# --- 0.04787039756774902 seconds ---
#
# Now on split# 5 char_tfidf JP
# Training until validation scores don't improve for 300 rounds
# [100]	valid_0's auc: 0.613612	valid_0's binary_logloss: 0.674906
# [200]	valid_0's auc: 0.61594	valid_0's binary_logloss: 0.666355
# [300]	valid_0's auc: 0.620657	valid_0's binary_logloss: 0.660886
# [400]	valid_0's auc: 0.624221	valid_0's binary_logloss: 0.657606
# [500]	valid_0's auc: 0.625074	valid_0's binary_logloss: 0.655596
# [600]	valid_0's auc: 0.624982	valid_0's binary_logloss: 0.654123
# [700]	valid_0's auc: 0.624612	valid_0's binary_logloss: 0.653144
# [800]	valid_0's auc: 0.623823	valid_0's binary_logloss: 0.652358
# [900]	valid_0's auc: 0.623954	valid_0's binary_logloss: 0.651741
# Early stopping, best iteration is:
# [617]	valid_0's auc: 0.626214	valid_0's binary_logloss: 0.653557
# lgb 0.614939200926462 0.5884684226274195 0.6262137964692617
# --- 75.75627827644348 seconds ---
# cnb 0.6050955414012739 0.5964344941956883 0.6296875964165306
# --- 0.03789663314819336 seconds ---
#
#
#
# Performing training and classification on: kaggle_noNNnoSW word_tfidf JP
#
# Now on split# 1 word_tfidf JP
# Training until validation scores don't improve for 300 rounds
# [100]	valid_0's auc: 0.584581	valid_0's binary_logloss: 0.680653
# [200]	valid_0's auc: 0.593251	valid_0's binary_logloss: 0.674133
# [300]	valid_0's auc: 0.595837	valid_0's binary_logloss: 0.670705
# [400]	valid_0's auc: 0.595524	valid_0's binary_logloss: 0.668952
# [500]	valid_0's auc: 0.593212	valid_0's binary_logloss: 0.668755
# [600]	valid_0's auc: 0.590664	valid_0's binary_logloss: 0.669152
# Early stopping, best iteration is:
# [358]	valid_0's auc: 0.597956	valid_0's binary_logloss: 0.669211
# lgb 0.5868055555555556 0.5655753751681302 0.5979560171181466
# --- 57.44413757324219 seconds ---
# cnb 0.5868055555555556 0.5790869901624849 0.6131346485626583
# --- 0.03792691230773926 seconds ---
#
# Now on split# 2 word_tfidf JP
# Training until validation scores don't improve for 300 rounds
# [100]	valid_0's auc: 0.591469	valid_0's binary_logloss: 0.679633
# [200]	valid_0's auc: 0.596316	valid_0's binary_logloss: 0.674405
# [300]	valid_0's auc: 0.602985	valid_0's binary_logloss: 0.669318
# [400]	valid_0's auc: 0.605935	valid_0's binary_logloss: 0.6662
# [500]	valid_0's auc: 0.605435	valid_0's binary_logloss: 0.66474
# [600]	valid_0's auc: 0.604381	valid_0's binary_logloss: 0.664369
# [700]	valid_0's auc: 0.606666	valid_0's binary_logloss: 0.662905
# Early stopping, best iteration is:
# [429]	valid_0's auc: 0.60696	valid_0's binary_logloss: 0.665287
# lgb 0.5914351851851852 0.5704428779673669 0.6069604086845466
# --- 64.34088945388794 seconds ---
# cnb 0.5815972222222222 0.5735758059809236 0.6031359929197195
# --- 0.03689932823181152 seconds ---
#
# Now on split# 3 word_tfidf JP
# Training until validation scores don't improve for 300 rounds
# [100]	valid_0's auc: 0.583666	valid_0's binary_logloss: 0.679519
# [200]	valid_0's auc: 0.582705	valid_0's binary_logloss: 0.674196
# [300]	valid_0's auc: 0.586298	valid_0's binary_logloss: 0.671029
# [400]	valid_0's auc: 0.586443	valid_0's binary_logloss: 0.669677
# [500]	valid_0's auc: 0.584715	valid_0's binary_logloss: 0.6694
# [600]	valid_0's auc: 0.586117	valid_0's binary_logloss: 0.668413
# Early stopping, best iteration is:
# [344]	valid_0's auc: 0.588019	valid_0's binary_logloss: 0.669779
# lgb 0.5940938042848871 0.5700997668732789 0.5880188261164684
# --- 55.998395681381226 seconds ---
# cnb 0.5888824551244933 0.5802972425312851 0.6132904753089536
# --- 0.03740882873535156 seconds ---
#
# Now on split# 4 word_tfidf JP
# Training until validation scores don't improve for 300 rounds
# [100]	valid_0's auc: 0.588172	valid_0's binary_logloss: 0.680718
# [200]	valid_0's auc: 0.598015	valid_0's binary_logloss: 0.673979
# [300]	valid_0's auc: 0.601331	valid_0's binary_logloss: 0.670746
# [400]	valid_0's auc: 0.603007	valid_0's binary_logloss: 0.667791
# [500]	valid_0's auc: 0.602816	valid_0's binary_logloss: 0.666429
# [600]	valid_0's auc: 0.607615	valid_0's binary_logloss: 0.66376
# [700]	valid_0's auc: 0.608794	valid_0's binary_logloss: 0.662614
# [800]	valid_0's auc: 0.609092	valid_0's binary_logloss: 0.661931
# [900]	valid_0's auc: 0.609441	valid_0's binary_logloss: 0.661482
# [1000]	valid_0's auc: 0.609765	valid_0's binary_logloss: 0.661034
# [1100]	valid_0's auc: 0.61024	valid_0's binary_logloss: 0.661034
# [1200]	valid_0's auc: 0.609745	valid_0's binary_logloss: 0.661484
# [1300]	valid_0's auc: 0.610941	valid_0's binary_logloss: 0.660657
# Early stopping, best iteration is:
# [1042]	valid_0's auc: 0.610805	valid_0's binary_logloss: 0.660625
# lgb 0.6022003474232773 0.5729471155144021 0.6108053830576171
# --- 109.7208399772644 seconds ---
# cnb 0.5755645628257093 0.5713123678226314 0.6242405883441882
# --- 0.035902976989746094 seconds ---
#
# Now on split# 5 word_tfidf JP
# Training until validation scores don't improve for 300 rounds
# [100]	valid_0's auc: 0.611131	valid_0's binary_logloss: 0.675788
# [200]	valid_0's auc: 0.62556	valid_0's binary_logloss: 0.666483
# [300]	valid_0's auc: 0.624182	valid_0's binary_logloss: 0.662438
# [400]	valid_0's auc: 0.624959	valid_0's binary_logloss: 0.65959
# [500]	valid_0's auc: 0.624392	valid_0's binary_logloss: 0.657819
# Early stopping, best iteration is:
# [205]	valid_0's auc: 0.626693	valid_0's binary_logloss: 0.666007
# lgb 0.6132020845396642 0.5961370962547226 0.6266934248834587
# --- 45.689488887786865 seconds ---
# cnb 0.6039374638100753 0.5952510176390773 0.6281771876384892
# --- 0.03789639472961426 seconds ---
# processing file: kaggle_noNNnoSW_lgbfeatures
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <timed exec> in <module>
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2984             if is_iterator(key):
#    2985                 key = list(key)
# -> 2986             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    2987
#    2988         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
#    1284                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# -> 1285                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1286         else:
#    1287             try:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1090
#    1091         self._validate_read_indexer(
# -> 1092             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1093         )
#    1094         return keyarr, indexer
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1175                 raise KeyError(
#    1176                     "None of [{key}] are in the [{axis}]".format(
# -> 1177                         key=key, axis=self.obj._get_axis_name(axis)
#    1178                     )
#    1179                 )
#
# KeyError: "None of [Index(['MBTI', 'EI', 'SN', 'TF', 'JP'], dtype='object')] are in the [columns]"

# %%
# %%time

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer,TfidfTransformer
from sklearn.preprocessing import QuantileTransformer, quantile_transform

scaler=QuantileTransformer(random_state=seed) 
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state = seed)
result_list=[]
all_result_list=[]
result_fileDF=pd.DataFrame()
models=[('cnb',cnb),('rf',rf),('lgr',lgr),('svc',svc),('lgb',lgb)]

for filepath in file_list:
    result_list=[]
    dir = os.path.split(filepath)[0]
    file = os.path.split(filepath)[1].replace('.pickle','')
    print('processing file:',file)
    
    with open(filepath, 'rb') as handle:
        data = pickle.load(handle)
    
        label=data[['MBTI','EI','SN','TF','JP']]
    
    data['tokens']=data['tokens'].apply(lambda x: ' '.join(x))
    
    start_time = time.time()
    print('converting to tfidf')
    cCount_Vect=CountVectorizer(analyzer='char_wb', ngram_range=(2,3),min_df=50, max_df=0.95, max_features=1500)
    wCount_Vect=CountVectorizer(tokenizer = module2.dummy, preprocessor=module2.dummy, token_pattern=module2.dummy,
                           analyzer='char_wb', ngram_range=(2,3),min_df=50, max_df=0.95, max_features=1500)
    TFIDF_Trans=TfidfTransformer(use_idf=True, sublinear_tf=False)
    cTfidf_Vect=TfidfVectorizer(analyzer='char_wb', ngram_range=(2,3),min_df=50, max_df=0.95, max_features=1500)
    wTfidf_Vect=TfidfVectorizer(tokenizer = module2.dummy, preprocessor=module2.dummy, token_pattern=module2.dummy, 
                                ngram_range=(1,3),min_df=50, max_df=0.95, max_features=1500)
    
    char_tf, char_tf_top=module2.df2vector(data['tokens'], cCount_Vect, 1500)
    word_tf, word_tf_top=module2.df2vector(data['tokens'], wCount_Vect, 1500)
    
    char_tfidf, char_tfidf_top=module2.df2vector(data['tokens'], cTfidf_Vect, 1500)
    word_tfidf, word_tfidf_top=module2.df2vector(data['tokens'], wTfidf_Vect, 1500)
    print("--- %s seconds ---" % (time.time() - start_time))
    del data
    
    LIWC=module2.LIWC(LIWCPath,filepath)

    
    char_tf=scaler.fit_transform(char_tf)
    word_tf=scaler.fit_transform(word_tf)
    char_tfidf=scaler.fit_transform(char_tfidf)
    word_tfidf=scaler.fit_transform(word_tfidf)
    LIWC=scaler.fit_transform(LIWC)
    
    combo = np.hstack([LIWC,word_tfidf, char_tfidf, word_tf, char_tf])      
    
    
    
#     Emolex=module2.EmolexDF(data_tfidf,lexiconPath)
    
#     start_time = time.time()
#     print('converting to tfigm and rtfigm')
#     Count_Vect = CountVectorizer(tokenizer = module2.dummy, preprocessor=module2.dummy, 
#                                  token_pattern = module2.dummy, ngram_range = (1,3), min_df = 40, max_df = 0.95)
#     TF_Trans = TfidfTransformer(use_idf=False, sublinear_tf=False)
#     data_tfigm, data_rtfigm = module2.TFIGM(data['tokens'], label['JP'], count_vectorizer=Count_Vect,
#                                             TF_transformer=TF_Trans, num_features=1500, constant=7)
#     print("--- %s seconds ---" % (time.time() - start_time))
    
#     emo_tfidf = pd.concat([Emolex,data_tfidf],axis=1)

#     combo = np.hstack([LIWC,word_tfidf, char_tfidf])
    
#     features = [('data_tfidf',data_tfidf),('data_tfigm',data_tfigm),('data_rtfigm',data_rtfigm)]
#     features = [('LIWC',LIWC),('LIWC_tfidf',LIWC_tfidf), ('data_tfidf',data_tfidf)]
#     features = [('data_tfidf',data_tfidf)]
    
    features = [('combo',combo),('char_tf',char_tf), ('word_tf',word_tf)]
    for feature_name,feature in features:    
        X=feature
        for y_class in ['JP']:
            y=label[y_class]
            split = 0
            print('\n\n\nPerforming training and classification on:',file, feature_name, y_class)

            for train_index, test_index in skf.split(X, y):
                
                split += 1
                X_train, X_test = X[train_index,:],X[test_index,:]
                y_train, y_test = y[train_index],y[test_index]

                print('\nNow on split#',split, feature_name, y_class )
                for model_name, model in models:
                    result = {}
                    start_time = time.time()
                    if model_name == 'lgb':
                        lgb.fit(X_train,y_train,eval_set=[(X_test,y_test)],eval_metric='f1_score',
                                verbose=100,early_stopping_rounds=300)
                        y_pred =lgb.predict(X_test)
                        y_pred_proba = lgb.predict_proba(X_test)[:,1]
                        
                        
                    else:
                        model.fit(X_train,y_train)
                        y_pred =model.predict(X_test)
                        y_pred_proba = model.predict_proba(X_test)[:,1]
                    f1=f1_score(y_test, y_pred, average='macro') 
                    accuracy=accuracy_score(y_test, y_pred)
                    cm=confusion_matrix(y_test, y_pred)
                    auc=roc_auc_score(y_test, y_pred_proba)
                    seconds=time.time() - start_time
                    print(model_name, accuracy, f1,auc)
                    result['file'] = file
                    result['cv_split#'] = split
                    result['class'] = y_class
                    result['Feature'] = feature_name
                    result['model'] = model_name
                    result['CM'] = cm
                    result['Acc'] = accuracy
                    result['f1-macro'] = f1
                    result['auc'] = auc
                    result['time-s'] = seconds
                    result_list.append(result)
                    print("--- %s seconds ---" %seconds)
    all_result_list.extend(result_list)
    result_fileDF = pd.DataFrame(result_list)
    result_fileDF.to_csv(filepath.replace('.pickle','_result-v2.csv'))

# %%
result_STD=result_fileDF.groupby(['file','Feature','model','class']).std()[['Acc','f1-macro','auc','time-s']].rename({'Acc':'acc_sd','f1-macro':'f1-macro_sd','auc':'auc_sd','time-s':'time-s_sd'}, axis='columns')
result_mean=result_fileDF.groupby(['file','Feature','model','class']).mean()[['Acc','f1-macro','auc','time-s']].rename({'Acc':'acc_mean','f1-macro':'f1-macro_mean','auc':'auc_mean','time-s':'time-s_mean'}, axis='columns')
result_meanstd=pd.concat([result_mean,result_STD],axis=1).reset_index()
result_meanstd.to_csv(os.path.join(dir,'group_result_JP.csv'))

# %%
result_meanstd[result_meanstd['model']=='lgb'].groupby(['Feature']).mean()
# Out:
#              acc_mean  f1-macro_mean  auc_mean  time-s_mean    acc_sd  \
# Feature
# data_rtfigm  0.694728       0.678610  0.740512    82.246032  0.009366
# data_tfidf   0.697365       0.682148  0.744566    14.126507  0.008350
# data_tfigm   0.695535       0.678753  0.740820    88.560978  0.008170
#
#              f1-macro_sd    auc_sd  time-s_sd
# Feature
# data_rtfigm     0.008341  0.007966  18.509079
# data_tfidf      0.008709  0.006680   2.412570
# data_tfigm      0.008260  0.007616  16.749666

# %%
result_meanstd[(result_meanstd['Feature']=='data_tfidf') & ((result_meanstd['model'] =='lgb') | (result_meanstd['model'] =='svc'))]
# Out:
#                             file     Feature model class  acc_mean  \
# 4                         kaggle  data_tfidf   lgb    JP  0.649108
# 7                         kaggle  data_tfidf   svc    JP  0.626398
# 16             kaggle-uncensored  data_tfidf   lgb    JP  0.810378
# 19             kaggle-uncensored  data_tfidf   svc    JP  0.735907
# 28        kaggle-uncensored_noNN  data_tfidf   lgb    JP  0.687610
# 31        kaggle-uncensored_noNN  data_tfidf   svc    JP  0.639194
# 40  kaggle-uncensored_noNNnoSTOP  data_tfidf   lgb    JP  0.700405
# 43  kaggle-uncensored_noNNnoSTOP  data_tfidf   svc    JP  0.676085
# 52      kaggle-uncensored_noSTOP  data_tfidf   lgb    JP  0.816602
# 55      kaggle-uncensored_noSTOP  data_tfidf   svc    JP  0.746169
# 64                   kaggle_noNN  data_tfidf   lgb    JP  0.620405
# 67                   kaggle_noNN  data_tfidf   svc    JP  0.601728
# 76             kaggle_noNNnoSTOP  data_tfidf   lgb    JP  0.640808
# 79             kaggle_noNNnoSTOP  data_tfidf   svc    JP  0.620407
# 88                 kaggle_noSTOP  data_tfidf   lgb    JP  0.653606
# 91                 kaggle_noSTOP  data_tfidf   svc    JP  0.641385
#
#     f1-macro_mean  auc_mean  time-s_mean    acc_sd  f1-macro_sd    auc_sd  \
# 4        0.630538  0.685548    14.197496  0.008227     0.010025  0.006642
# 7        0.616415  0.663358   378.269269  0.010018     0.009066  0.011870
# 16       0.801322  0.880102    23.183925  0.010923     0.010561  0.008637
# 19       0.726484  0.803246   346.383254  0.005233     0.005979  0.002066
# 28       0.670537  0.732774    16.114421  0.009138     0.010541  0.005798
# 31       0.627301  0.680803   384.735688  0.015743     0.013959  0.011549
# 40       0.686537  0.756012     9.646559  0.006865     0.006846  0.007774
# 43       0.662636  0.719683   375.964802  0.015999     0.015243  0.013669
# 52       0.807816  0.884251    19.232733  0.010010     0.009911  0.010947
# 55       0.736473  0.815495  7549.354707  0.007399     0.006176  0.005899
# 64       0.601775  0.647790    10.827916  0.005952     0.006543  0.003797
# 67       0.590483  0.633767   363.910571  0.009877     0.008647  0.009250
# 76       0.623392  0.675241     7.266829  0.004739     0.006426  0.004942
# 79       0.607858  0.660009   371.019012  0.016202     0.015095  0.011959
# 88       0.635269  0.694811    12.542177  0.010947     0.008820  0.004905
# 91       0.630271  0.680210   355.054912  0.009708     0.009105  0.007515
#
#        time-s_sd
# 4       1.494661
# 7      10.029106
# 16      4.456938
# 19      3.507872
# 28      2.738925
# 31     18.150506
# 40      1.004304
# 43      5.057665
# 52      1.880902
# 55  14400.501813
# 64      2.648654
# 67      2.943539
# 76      1.670084
# 79      1.068120
# 88      3.406092
# 91      0.179645

# %%
result_meanstd=pd.concat([result_mean,result_STD],axis=1)

# %%
filepath
# Out:
# 'Source Code\\Preprocessed\\Wassa\\50g_noSW.pickle'

# %%
result_meanstd.to_csv('Source Code\\Preprocessed\\Wassa\\CVmean_result_JP.csv')

# %%
result_meanstd=result_meanstd[['class','acc_mean', 'f1-macro_mean', 'auc_mean', 'time-s_mean', 'acc_sd',
       'f1-macro_sd', 'auc_sd', 'time-s_sd']].reset_index()

# %%
import lightgbm as lgb
lgb = lgb.LGBMClassifier(objective='binary',metric='auc,binary_logloss',boosting_type='gbdt', class_weight='balanced',
                               learning_rate=0.005,n_estimators=10000,
                              random_state=seed,n_jobs=10)
lgb
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight='balanced',
#                colsample_bytree=1.0, importance_type='split',
#                learning_rate=0.005, max_depth=-1, metric='auc,binary_logloss',
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=10000, n_jobs=10, num_leaves=31, objective='binary',
#                random_state=123, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
# %%time
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score , roc_auc_score
from sklearn.metrics import confusion_matrix

skf = StratifiedKFold(n_splits=4, shuffle=True, random_state = 123)
model =rf
 
X=kaggle_tfidf.iloc[:,:1500]

y=kaggle_label['SN']

for train_index, test_index in skf.split(X, y):
    X_train, X_test = X.iloc[train_index,:],X.iloc[test_index,:]
    y_train, y_test = y[train_index],y[test_index]
    
#     lgb.fit(X_train,y_train,eval_set=[(X_test,y_test)],eval_metric='f1_score',verbose=100,early_stopping_rounds=1000)
#     y_pred =lgb.predict(X_test)
    model.fit(X_train,y_train)
    y_pred =model.predict(X_test)
#     y_pred_proba = model.predict_proba(X_test)[:,1]
    f1=f1_score(y_test, y_pred, average='macro') 
    accuracy=accuracy_score(y_test, y_pred)
    cm=confusion_matrix(y_test, y_pred)
#     auc=roc_auc_score(y_test, y_pred_proba)
    print(cm, accuracy, f1)

# %%
all_result_list=[]
for file in file_list:
    all_result_list.append(pd.read_csv(file, index_col=0))
result_fileDF=pd.concat(all_result_list,axis=0)
result_fileDF.to_csv('Source Code\\Processed\\Kaggle\\resultJP.csv')
